# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
eventos = pd.read_csv('datos_tp1/Data/events.csv', low_memory=False)

# %%
eventos.columns
# Out:
# Index(['timestamp', 'event', 'person', 'url', 'sku', 'model', 'condition',
#        'storage', 'color', 'skus', 'search_term', 'staticpage',
#        'campaign_source', 'search_engine', 'channel', 'new_vs_returning',
#        'city', 'region', 'country', 'device_type', 'screen_resolution',
#        'operating_system_version', 'browser_version'],
#       dtype='object')

# %%
leadsPorPersona = eventos[eventos['event']=='lead']['person'].value_counts()
leadsPorPersona.head()
# Out:
# 97e0bcf2    16
# 52a4edd3    11
# 58692743     8
# 8dd8c1b4     6
# aaf00dd9     5
# Name: person, dtype: int64

# %%
asd = eventos[eventos['person']=='97e0bcf2']
asd[asd['event'].str.contains('lead|conversion')]
# Out:
#                   timestamp       event    person  url     sku  \
# 593706  2018-01-12 21:37:38        lead  97e0bcf2  NaN     NaN
# 593728  2018-03-08 17:26:27        lead  97e0bcf2  NaN     NaN
# 593842  2018-03-09 08:59:10        lead  97e0bcf2  NaN     NaN
# 593843  2018-03-09 09:02:11        lead  97e0bcf2  NaN     NaN
# 593844  2018-03-09 11:04:23        lead  97e0bcf2  NaN     NaN
# 593847  2018-03-09 13:31:41        lead  97e0bcf2  NaN     NaN
# 593863  2018-03-09 15:07:05        lead  97e0bcf2  NaN     NaN
# 593864  2018-03-09 16:05:35        lead  97e0bcf2  NaN     NaN
# 593901  2018-03-10 02:48:14  conversion  97e0bcf2  NaN  9273.0
# 593923  2018-03-11 23:31:17        lead  97e0bcf2  NaN     NaN
# 593932  2018-03-12 09:01:48        lead  97e0bcf2  NaN     NaN
# 593933  2018-03-12 10:27:43        lead  97e0bcf2  NaN     NaN
# 593934  2018-03-12 11:44:15        lead  97e0bcf2  NaN     NaN
# 593943  2018-03-12 13:08:01        lead  97e0bcf2  NaN     NaN
# 593946  2018-03-12 14:04:06        lead  97e0bcf2  NaN     NaN
# 593948  2018-03-12 15:16:09        lead  97e0bcf2  NaN     NaN
# 594184  2018-06-15 08:53:27        lead  97e0bcf2  NaN     NaN
#
#                           model  condition storage  color skus  \
# 593706    Motorola Moto G4 Plus        NaN     NaN    NaN  NaN
# 593728  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593842  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593843  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593844  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593847  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593863  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593864  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593901  Samsung Galaxy J7 Prime  Muito Bom    32GB  Preto  NaN
# 593923  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593932  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593933  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593934  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593943  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593946  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 593948  Samsung Galaxy J7 Prime        NaN     NaN    NaN  NaN
# 594184    Samsung Galaxy J7 PRO        NaN     NaN    NaN  NaN
#
#              ...       search_engine channel new_vs_returning city region  \
# 593706       ...                 NaN     NaN              NaN  NaN    NaN
# 593728       ...                 NaN     NaN              NaN  NaN    NaN
# 593842       ...                 NaN     NaN              NaN  NaN    NaN
# 593843       ...                 NaN     NaN              NaN  NaN    NaN
# 593844       ...                 NaN     NaN              NaN  NaN    NaN
# 593847       ...                 NaN     NaN              NaN  NaN    NaN
# 593863       ...                 NaN     NaN              NaN  NaN    NaN
# 593864       ...                 NaN     NaN              NaN  NaN    NaN
# 593901       ...                 NaN     NaN              NaN  NaN    NaN
# 593923       ...                 NaN     NaN              NaN  NaN    NaN
# 593932       ...                 NaN     NaN              NaN  NaN    NaN
# 593933       ...                 NaN     NaN              NaN  NaN    NaN
# 593934       ...                 NaN     NaN              NaN  NaN    NaN
# 593943       ...                 NaN     NaN              NaN  NaN    NaN
# 593946       ...                 NaN     NaN              NaN  NaN    NaN
# 593948       ...                 NaN     NaN              NaN  NaN    NaN
# 594184       ...                 NaN     NaN              NaN  NaN    NaN
#
#        country device_type screen_resolution operating_system_version  \
# 593706     NaN         NaN               NaN                      NaN
# 593728     NaN         NaN               NaN                      NaN
# 593842     NaN         NaN               NaN                      NaN
# 593843     NaN         NaN               NaN                      NaN
# 593844     NaN         NaN               NaN                      NaN
# 593847     NaN         NaN               NaN                      NaN
# 593863     NaN         NaN               NaN                      NaN
# 593864     NaN         NaN               NaN                      NaN
# 593901     NaN         NaN               NaN                      NaN
# 593923     NaN         NaN               NaN                      NaN
# 593932     NaN         NaN               NaN                      NaN
# 593933     NaN         NaN               NaN                      NaN
# 593934     NaN         NaN               NaN                      NaN
# 593943     NaN         NaN               NaN                      NaN
# 593946     NaN         NaN               NaN                      NaN
# 593948     NaN         NaN               NaN                      NaN
# 594184     NaN         NaN               NaN                      NaN
#
#        browser_version
# 593706             NaN
# 593728             NaN
# 593842             NaN
# 593843             NaN
# 593844             NaN
# 593847             NaN
# 593863             NaN
# 593864             NaN
# 593901             NaN
# 593923             NaN
# 593932             NaN
# 593933             NaN
# 593934             NaN
# 593943             NaN
# 593946             NaN
# 593948             NaN
# 594184             NaN
#
# [17 rows x 23 columns]

# %%
leads = eventos[eventos['event'] == 'lead'][['person','model']]
cantLeadsPorModelo = leads.groupby('model').agg(np.size)

cantLeadsPorModelo = cantLeadsPorModelo[cantLeadsPorModelo['person'] > 3].sort_values(by='person')
display(cantLeadsPorModelo)
cantLeadsPorModelo.tail(10).plot(kind= 'barh')
plt.show()
# Out:
#                              person
# model
# LG K10                            4
# iPhone 5c                         4
# Samsung Galaxy S7 Edge            4
# Samsung Galaxy J5 Prime           4
# Motorola Moto Z2 Play             4
# Motorola Moto Z2 Force            4
# iPhone X                          4
# Motorola Moto G4 Play DTV         5
# iPhone 7                          5
# iPhone 5s                         5
# Motorola Moto G2 3G Dual          5
# Samsung Galaxy Note 5             5
# LG X Power                        5
# iPhone SE                         5
# LG K4                             5
# LG K10 TV                         6
# Lenovo Vibe A7010 Dual Chip       7
# iPhone 8 Plus                     7
# Samsung Galaxy J7 PRO             8
# Motorola Moto G5S Plus            9
# iPhone 7 Plus                     9
# LG K10 Novo                      12
# iPhone 6                         12
# Samsung Galaxy On 7              15
# Motorola Moto G5 Plus            15
# Samsung Galaxy A9 Pro 2016       15
# Motorola Moto G4 Plus            20
# iPhone 8                         20
# iPhone 6S                        21
# Samsung Galaxy J7 Prime          26
# iPhone 6S Plus                   31
# iPhone 6 Plus                    35

# %%
compras = eventos[eventos['event']=='conversion'][['model', 'person']]

# %%
comprasSobreLeads = pd.merge(leads, compras, how='inner', on=['person', 'model'])
comprasSobreLeads.head()
# Out:
#      person                   model
# 0  01db2fe6       Samsung Galaxy J5
# 1  19b38ba2     Sony Xperia M4 Aqua
# 2  19b38ba2             LG G4 H815P
# 3  1db2e967  Samsung Galaxy J1 2016
# 4  1db2e967  Samsung Galaxy J1 2016

# %%
comprasSobreLeadsOrdenada = comprasSobreLeads.groupby('model').agg(np.size).sort_values(by='person', ascending=False)
comprasSobreLeadsOrdenada
# Out:
#                                    person
# model
# Samsung Galaxy J7 Prime                14
# Motorola Moto G4 Plus                  13
# iPhone 6S Plus                          6
# Motorola Moto G3 4G                     3
# iPhone 6S                               2
# Samsung Galaxy A9 Pro 2016              2
# iPhone 5c                               2
# Samsung Galaxy Gran Prime Duos TV       2
# Samsung Galaxy J1 2016                  2
# Asus Zenfone 3 Max 16 GB                1
# Samsung Galaxy S8                       1
# iPhone 5s                               1
# iPhone 4S                               1
# Sony Xperia M4 Aqua                     1
# Samsung Galaxy J2 Prime TV              1
# Samsung Galaxy S6 Flat                  1
# Samsung Galaxy J5                       1
# LG G4 H815P                             1
# Samsung Galaxy Gran Prime 3G Duos       1
# Motorola Moto Z                         1
# Motorola Moto X Force                   1
# Motorola Moto G5                        1
# iPhone 7 Plus                           1

# %%
comprasSobreLeads['model'].value_counts().sort_values().tail(15).plot(kind='barh')
plt.show()

# %%
#cantLeadsPorModelo comprasSobreLeadsOrdenada

# %%
juntas = pd.merge(cantLeadsPorModelo, comprasSobreLeadsOrdenada, how='inner', on=['model'])
juntas.columns = ['leads','conversion']
juntas
# Out:
#                             leads  conversion
# model
# iPhone 5c                       4           2
# iPhone 5s                       5           1
# iPhone 7 Plus                   9           1
# Samsung Galaxy A9 Pro 2016     15           2
# Motorola Moto G4 Plus          20          13
# iPhone 6S                      21           2
# Samsung Galaxy J7 Prime        26          14
# iPhone 6S Plus                 31           6

# %%
juntas['no_conversion'] = juntas['leads'] - juntas['conversion']
juntas = juntas.sort_values(by='leads', ascending=False)
juntas
# Out:
#                             leads  conversion  no_conversion
# model
# iPhone 6S Plus                 31           6             25
# Samsung Galaxy J7 Prime        26          14             12
# iPhone 6S                      21           2             19
# Motorola Moto G4 Plus          20          13              7
# Samsung Galaxy A9 Pro 2016     15           2             13
# iPhone 7 Plus                   9           1              8
# iPhone 5s                       5           1              4
# iPhone 5c                       4           2              2

# %%
# Make data: I have 3 groups and 7 subgroups
#group_names=['groupA', 'groupB', 'groupC']
group_names=juntas.index
#group_size=[12,11,30]
group_size=juntas['leads']

subgroup_names=['Si', 'No', 'Si', 'No', 'Si', 'No', 'Si', 'No', 'Si', 'No', 'Si', 'No', 'Si', 'No', 'Si', 'No']
subgroup_size=[6,25,14,12,2,19,13,7,2,13,1,8,1,4,2,2]
 
# Create colors
a, b, c, d = [plt.cm.Blues, plt.cm.Reds, plt.cm.Greens, plt.cm.Oranges]
 
# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=2.3, labels=group_names, colors=[a(0.6), b(0.6), c(0.6), d(0.6),a(0.6), b(0.6), c(0.6), d(0.6)])
plt.setp( mypie, width=1.2, edgecolor='white')
 
# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=1.8, labels=subgroup_names, labeldistance=0.80, colors=[a(0.5), a(0.4), b(0.5), b(0.4), c(0.5), c(0.4), d(0.5), d(0.4),a(0.5), a(0.4), b(0.5), b(0.4), c(0.5), c(0.4), d(0.5), d(0.4)])
plt.setp( mypie2, width=0.7, edgecolor='white')
plt.margins(0,0)

#plt.title('Cantidad de veces puesto en lead por modelo de telefono', fontsize=20)

# show it
plt.show()
